# %% [markdown]
# # Gradient Boosting Classification
# Interactive walkthrough for the wine dataset.

# %%
import json

from src.config import CONFIG
from src.pipeline import train_and_persist

metrics = train_and_persist(CONFIG)
print(json.dumps(metrics, indent=2))

# %%
from src.inference import get_service, GradientBoostingClassificationRequest

service = get_service()
sample = GradientBoostingClassificationRequest(
    alcohol=13.2,
    malic_acid=1.78,
    ash=2.14,
    alcalinity_of_ash=11.2,
    magnesium=100.0,
    total_phenols=2.65,
    flavanoids=2.76,
    nonflavanoid_phenols=0.26,
    proanthocyanins=1.28,
    color_intensity=4.38,
    hue=1.05,
    od280_od315_of_diluted_wines=3.4,
    proline=1050.0,
,
]}],
:{
:{
:
3
,
:
,
:
},
:{
:
,
:
3.12
,
:
,
:
}},
:4,
:5}
