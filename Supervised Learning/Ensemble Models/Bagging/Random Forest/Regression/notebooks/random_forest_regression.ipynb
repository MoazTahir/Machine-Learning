# %% [markdown]
# # Random Forest Regression Walkthrough
# Hands-on exploration of the California housing regressor.

# %%
import json

from src.config import CONFIG
from src.pipeline import train_and_persist

metrics = train_and_persist(CONFIG)
print(json.dumps(metrics, indent=2))

# %%
from src.inference import get_service, RandomForestRegressionRequest

service = get_service()
sample = RandomForestRegressionRequest(
    median_income=6.32,
    house_age=34.0,
    average_rooms=5.4,
    average_bedrooms=1.1,
    population=980.0,
    average_occupancy=2.8,
    latitude=37.88,
    longitude=-122.23,
,
]}],
:{
:{
:
3
,
:
,
:
},
:{
:
,
:
3.12
,
:
,
:
}},
:4,
:5}
